# %%
import pandas as pd

df = pd.read_csv("./divided.csv")
df.describe()
df = df.iloc[: , :-97]
df
# Out:
#                     Unnamed: 0  \
# 0     NL_22501-2020-001391.txt
# 1     NL_32201-2018-011699.txt
# 2       NL_130-2019-000021.txt
# 3       NL_133-2019-009493.txt
# 4     NL_10204-2020-013156.txt
# ...                        ...
# 3982    NL_139-2021-014406.txt
# 3983    NL_118-2021-013426.txt
# 3984  NL_14903-2021-013779.txt
# 3985    NL_330-2021-011791.txt
# 3986    NL_227-2019-014524.txt
#
#                                                   title  \
# 0     Paritair subcomité voor de bedienden van de in...
# 1     Service public fédéral Emploi, Travail et Conc...
# 2     Paritair Comité voor het drukkerij-, grafische...
# 3     PARITAIR COMITE VOOR HET TABAKSBEDRIJF (PC 133...
# 4     Paritair Subcomité voor het bedrijf van de zan...
# ...                                                 ...
# 3982  Neerlegging-Dépôt: 10/12/2021 Regist.-Enregist...
# 3983  Federale overheidsdienst Werkgelegenheid, Arbe...
# 3984  Collectieve arbeidsovereenkomst van 18 novembe...
# ...

# %%
df.to_csv("divided_reduced.csv")
